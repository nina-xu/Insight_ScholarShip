# %%
import pandas as pd
import numpy as np

# %%
# read data
data = pd.read_csv('Data/Data Merged.csv')
data.head()
# Out:
#    UNITID  EFFYLEV  LSTUDY XEYTOTLT  EFYTOTLT XEYTOTLM  EFYTOTLM XEYTOTLW  \
# 0  100654        2       1        R      5207        R      2286        R
# 1  100663        2       1        R     13308        R      5528        R
# 2  100706        2       1        R      7519        R      4287        R
# 3  100724        2       1        R      5229        R      2024        R
# 4  100751        2       1        R     35625        R     15883        R
#
#    EFYTOTLW XEFYAIAT  ...  GRWHITW_rate GR2MORT_rate  GR2MORM_rate  \
# 0      2921        R  ...      0.500000     0.333333      0.333333
# 1      7780        R  ...      0.597701     0.444444      0.346154
# 2      3232        R  ...      0.538012     0.666667      0.000000
# 3      3205        R  ...      0.200000     0.000000      0.000000
# 4     19742        R  ...      0.728270     0.604839      0.568627
#
#   GR2MORW_rate  GRUNKNT_rate GRUNKNM_rate  GRUNKNW_rate GRNRALT_rate  \
# 0     0.333333      0.000000     0.000000           0.0     0.000000
# 1     0.500000      0.454545     0.500000           0.0     0.590909
# 2     1.000000      0.551724     0.526316           0.6     0.571429
# 3     0.000000      0.333333     0.000000           0.5     0.428571
# 4     0.630137      1.000000     0.000000           1.0     0.729323
#
#    GRNRALM_rate GRNRALW _rate
# 0      0.000000      0.000000
# 1      0.461538      0.777778
# 2      0.615385      0.000000
# 3      0.400000      0.500000
# 4      0.717647      0.750000
#
# [5 rows x 300 columns]

# %% [markdown]
# # Calculate graduation rate

# %%
# keep only non-zero international completers, & at least 3 international students in 2017 cohort
data_intl_grad = data[data.GRNRALT_x > 0] 
data_intl_grad = data_intl_grad[data_intl_grad.GRNRALT_y > 2] 
data_intl_grad.shape # (1222, 300)
# Out:
# (1222, 300)

# %%
#'GRTOTLT', 'GRNRALT'
import matplotlib.pyplot as plt
plt.subplot(1,2,1)
plt.hist(data_intl_grad['GRTOTLT_rate'])
plt.title('grand total')
plt.xlabel('graduation rate')
plt.subplot(1,2,2)
plt.hist(data_intl_grad['GRNRALT_rate']) 
plt.title('international students')
plt.xlabel('graduation rate')
# Out:
# Text(0.5, 0, 'graduation rate')

# %%
# calculate an adjusted proportion with Bayesian formula
# but first, look at a general distribution of 
plt.subplot(1,2,1)
plt.hist(data_intl_grad['GRNRALT_rate']/data_intl_grad['GRTOTLT_rate'])
plt.subplot(1,2,2)
plt.hist(graduation_ratio)
# most are close to 1
# so I can use the grand total proportion as my prior
# Out:
# (array([ 93., 952., 142.,  27.,   5.,   2.,   0.,   0.,   0.,   1.]),
#  array([0.3705458 , 0.82406767, 1.27758955, 1.73111142, 2.1846333 ,
#         2.63815518, 3.09167705, 3.54519893, 3.99872081, 4.45224268,
#         4.90576456]),
#  <a list of 10 Patch objects>)

# %%
GRNRALT_rate_adj = (data_intl_grad['GRNRALT_x'] + 10*data_intl_grad['GRTOTLT_rate'])/(data_intl_grad['GRNRALT_y'] + 10)
GRNRALT_rate_adj.describe()
graduation_ratio = GRNRALT_rate_adj/data_intl_grad['GRTOTLT_rate']
graduation_ratio.describe()
data_intl_grad['GRNRALT_rate_adj'] = GRNRALT_rate_adj
data_intl_grad['graduation_ratio'] = graduation_ratio

# %%
plt.hist(GRNRALT_rate_adj)
# Out:
# (array([ 26.,  62.,  74., 152., 193., 233., 199., 136.,  98.,  49.]),
#  array([0.10853396, 0.19768056, 0.28682717, 0.37597377, 0.46512038,
#         0.55426698, 0.64341358, 0.73256019, 0.82170679, 0.9108534 ,
#         1.        ]),
#  <a list of 10 Patch objects>)

# %%
# look at who have >90% completion rate
data_intl_grad[data_intl_grad.GRNRALT_rate>0.9][['INSTNM','ranking_US_news','GRNRALT_x','GRNRALT_y','GRTOTLT_rate','GRNRALT_rate_adj']]
# they are a mix of very great schools and schools with very small international enrollment
# Out:
#                                                  INSTNM  ranking_US_news  \
# 25                                 University of Mobile              NaN
# 36                                  Spring Hill College              NaN
# 86                                      Hendrix College              NaN
# 94                              Philander Smith College              NaN
# 118                       California Baptist University              NaN
# 158                         Concordia University-Irvine              NaN
# 165                          Columbia College Hollywood              NaN
# 183   FIDM-Fashion Institute of Design & Merchandisi...              NaN
# 197                                 Harvey Mudd College              NaN
# 310                                  Simpson University              NaN
# 347                                    Colorado College              NaN
# 412                                 Wesleyan University              NaN
# 414                                     Yale University              3.0
# 426                               Georgetown University             24.0
# 435                          Bethune-Cookman University              NaN
# 536                        The Art Institute of Atlanta              NaN
# 559                                    Emory University             21.0
# 622                                  Bradley University              NaN
# 625                               University of Chicago              6.0
# 689                                   Principia College              NaN
# 709           Southern Illinois University-Edwardsville            293.0
# 718                                     Wheaton College              NaN
# 725                                   DePauw University              NaN
# 730              Grace College and Theological Seminary              NaN
# 751                            University of Notre Dame             15.0
# 754              University of Saint Francis-Fort Wayne              NaN
# 769                                 Divine Word College              NaN
# 778                                    Grinnell College              NaN
# 787                                      Luther College              NaN
# 857                                       Berea College              NaN
# ...                                                 ...              ...
# 2017                              Lock Haven University              NaN
# 2056                         University of Pennsylvania              6.0
# 2076            Shippensburg University of Pennsylvania              NaN
# 2077           Slippery Rock University of Pennsylvania              NaN
# 2079                             Susquehanna University              NaN
# 2080                                 Swarthmore College              NaN
# 2096                                     Wilson College              NaN
# 2098                                   Brown University             14.0
# 2116         Citadel Military College of South Carolina              NaN
# 2197                                     Rhodes College              NaN
# 2214                              Vanderbilt University             15.0
# 2225                                     Austin College              NaN
# 2256                          Hardin-Simmons University            125.0
# 2312                              St. Mary's University              NaN
# 2320                     Southwestern Christian College              NaN
# 2374                                  Champlain College              NaN
# 2415                      University of Mary Washington              NaN
# 2427                             Randolph-Macon College              NaN
# 2428                                   Randolph College              NaN
# 2446                 University of Virginia-Main Campus             28.0
# 2484                        Pacific Lutheran University              NaN
# 2533                        Cardinal Stritch University            293.0
# 2534                                 Carroll University              NaN
# 2540                                Lakeland University              NaN
# 2588                                Stanford University              6.0
# 2696                         Soka University of America              NaN
#
# [122 rows x 6 columns]

# %%
# look at who have graduation ratio > 3
data_intl_grad[data_intl_grad.graduation_ratio>2][['INSTNM','ranking_US_news','GRNRALT_x','GRNRALT_y','GRTOTLT_rate','GRNRALT_rate_adj']]
# they are a mix of very great schools and schools with very small international enrollment
# for now, I'm not worrying about it because all >2 schools either don't have a ranking or have a 293 ranking
# Out:
#                                                  INSTNM  ranking_US_news  \
# 70                University of Arkansas at Little Rock            293.0
# 423              University of the District of Columbia              NaN
# 463                                Full Sail University              NaN
# 470   AI Miami International University of Art and D...              NaN
# 638                                East-West University              NaN
# 792                                  Ashford University              NaN
# 1341                         College of Southern Nevada              NaN
# 1879                                 Cameron University              NaN
# 2340                          Texas Southern University            293.0
# 2494                              Skagit Valley College              NaN
#
#       GRNRALT_x  GRNRALT_y  GRTOTLT_rate  GRNRALT_rate_adj
# 70         22.0       28.0      0.319908          0.663134
# 423        13.0       30.0      0.159021          0.364755
# 463        26.0       34.0      0.265437          0.651236
# 470        30.0       36.0      0.293046          0.715880
# 638         4.0       13.0      0.109312          0.221440
# 792        12.0       24.0      0.076533          0.375451
# 1341       25.0       87.0      0.086373          0.266636
# 1879       19.0       37.0      0.179487          0.442444
# 2340       15.0       20.0      0.233654          0.577885
# 2494       17.0       23.0      0.212121          0.579431

# %% [markdown]
# # MVP

# %%
data_274_intl_grad_national_u = data_intl_grad.dropna(subset = ['ranking_US_news','good_for_intl_US_news'])
print(data_274_intl_grad_national_u.shape) # (274, 302)
data_274_intl_grad_national_u[['good_for_intl_US_news','diverse_ind','graduation_ratio']]
# Out:
# (274, 302)
#       good_for_intl_US_news  diverse_ind  graduation_ratio
# 1                       1.0     0.606364          1.080186
# 2                       0.0     0.532520          1.102261
# 4                       1.0     0.394760          1.069330
# 8                       0.0     0.358513          0.761368
# 32                      0.0     0.317563          0.961702
# 41                      0.0     0.750486          1.825490
# 45                      1.0     0.699164          1.161981
# 47                      1.0     0.676080          1.092839
# 74                      1.0     0.417626          1.229120
# 84                      0.0     0.334221          1.029260
# 111                     0.0     0.721735          0.873806
# 114                     1.0     0.698830          1.025756
# 120                     1.0     0.719664          0.942396
# 130                     1.0     0.699732          1.031582
# 137                     0.0     0.784336          0.979011
# 138                     0.0     0.793248          0.912787
# 139                     1.0     0.779072          0.907981
# 140                     1.0     0.796794          0.968907
# 141                     1.0     0.708023          0.822429
# 142                     1.0     0.801013          0.915750
# 143                     0.0     0.779023          0.993990
# 144                     1.0     0.753916          1.064214
# 156                     0.0     0.647562          0.965000
# 211                     0.0     0.715131          1.002836
# 233                     0.0     0.741794          0.903991
# 267                     0.0     0.735760          0.800545
# 271                     1.0     0.730257          0.974346
# 290                     1.0     0.772052          0.802788
# 291                     1.0     0.705563          0.964899
# 295                     0.0     0.838346          0.886602
# ...                     ...          ...               ...
# 2331                    1.0     0.724140          0.961129
# 2332                    1.0     0.747474          1.052829
# 2335                    1.0     0.470906          1.028213
# 2341                    1.0     0.596807          0.936008
# 2357                    1.0     0.316269          0.985538
# 2366                    0.0     0.343069          1.174782
# 2369                    1.0     0.553997          1.147346
# 2386                    1.0     0.362654          1.000461
# 2391                    1.0     0.626587          0.967669
# 2392                    0.0     0.631453          1.066327
# 2402                    1.0     0.742766          0.961311
# 2405                    0.0     0.091645          0.618182
# 2422                    1.0     0.690535          1.168804
# 2443                    1.0     0.545690          0.878980
# 2445                    1.0     0.710396          0.966287
# 2446                    1.0     0.652251          0.977357
# 2470                    0.0     0.482225          0.692272
# 2491                    0.0     0.631981          0.986086
# 2492                    0.0     0.799502          0.884294
# 2501                    1.0     0.611593          1.036955
# 2502                    1.0     0.804561          0.987809
# 2528                    0.0     0.374644          1.016810
# 2536                    0.0     0.432667          0.964466
# 2537                    1.0     0.386572          1.035615
# 2544                    1.0     0.489219          0.981612
# 2565                    1.0     0.463129          0.984507
# 2577                    1.0     0.473421          0.991818
# 2588                    1.0     0.812678          0.980222
# 2589                    1.0     0.585346          1.023197
# 2851                    0.0     0.677656          0.986921
#
# [274 rows x 3 columns]

# %%
# gotta do some EDA, right?
x_variables = ['diverse_ind','graduation_ratio','GRNRALT_rate','tuition_US_news', 'ranking_US_news','good_for_intl_US_news']
for i in range(6):
    plt.subplot(2,3,i+1)
    plt.scatter(data_274_intl_grad_national_u[x_variables[i]], data_274_intl_grad_national_u['intl_pct'])
    plt.xlabel(x_variables[i])
    plt.ylabel('intl_pct')

# %%
plt.scatter(data_274_intl_grad_national_u['GRNRALT_rate'], data_274_intl_grad_national_u['intl_pct'])

# %%
from sklearn.model_selection import train_test_split
np.random.seed(922)
train, test = train_test_split(data_274_intl_grad_national_u, test_size = 0.3)

# %%
from sklearn.linear_model import LinearRegression
linear_model = LinearRegression(normalize = True)
result = linear_model.fit(
    X = train[['good_for_intl_US_news','diverse_ind','GRNRALT_rate','tuition_US_news', 'ranking_US_news']], 
    y = train['intl_pct'])
linear_fit = linear_model.predict(
    test[['good_for_intl_US_news','diverse_ind','GRNRALT_rate','tuition_US_news', 'ranking_US_news']])

result.coef_
# note that later on once I have a better target, I should substitute 'GRNRALT_rate' with 'graduation_ratio'
# Out:
# array([ 5.65314916e-01,  1.41695328e+01,  9.05888191e-01,  6.85335493e-05,
#        -1.32668367e-02])

# %%
pd.Series(linear_fit).describe()
# Out:
# count    83.000000
# mean      7.042120
# std       3.475438
# min      -2.577245
# 25%       4.538459
# 50%       7.305304
# 75%       9.515209
# max      13.415878
# dtype: float64

# %%
plt.scatter(test['intl_pct'], linear_fit)
plt.xlabel('y')
plt.ylabel('y hat')

# %%
from sklearn.metrics import explained_variance_score, mean_squared_error, r2_score, mean_absolute_error
print('explained_variance_score',explained_variance_score(y_true = test['intl_pct'], y_pred = linear_fit))
print('mean_squared_error',mean_squared_error(y_true = test['intl_pct'], y_pred = linear_fit))
print('r2_score',r2_score(y_true = test['intl_pct'], y_pred = linear_fit))
print('mean_absolute_error',mean_absolute_error(y_true = test['intl_pct'], y_pred = linear_fit))
# Out:
# explained_variance_score 0.43297636000015727
# mean_squared_error 14.032022710306649
# r2_score 0.3914465590462777
# mean_absolute_error 3.046857693061481
